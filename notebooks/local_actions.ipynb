# %%
# %reload_ext autoreload
# %autoreload 2

# %%
#import cortex
import os
#from pathlib import Path
from image_pipeline.utils import debug_utils

# %%
# LOAD SKILL MODULES
ident_colors = debug_utils.load_skill_module('ident_colors')
ident_bounding_boxes = debug_utils.load_skill_module('ident_bounding_boxes')
ident_landmarks = debug_utils.load_skill_module('ident_landmarks')

# %%
# IDENTIFY COLORS SKILL
colors_msg= debug_utils.call_cortex_function(ident_colors.main, payload={'ds_name': 'bill/test_images'})
ident_colors.API.decode_dataframe_message(colors_msg)
# Out:
# payload: ['ds_name']
#               comment                                          image_url  \
# 0        Eiffel Tower  https://www.kids-world-travel-guide.com/images...
# 1          Great Wall  https://www.kids-world-travel-guide.com/images...
# 2          Red Square  https://www.kids-world-travel-guide.com/images...
# 3       Leaning Tower  https://www.kids-world-travel-guide.com/images...
# 4      Great Pyramids  https://www.kids-world-travel-guide.com/images...
# 5  Sydney Opera House  https://www.kids-world-travel-guide.com/images...
# 6           Taj Mahal  https://www.kids-world-travel-guide.com/images...
#
#                                      dominant_colors
# 0  [{'fractionOfPixels': 0.68, 'rgbValues': 'rgb_...
# 1                                                 []
# 2  [{'fractionOfPixels': 0.12, 'rgbValues': 'rgb_...
# 3                                                 []
# 4  [{'fractionOfPixels': 0.14, 'rgbValues': 'rgb_...
# 5                                                 []
# 6  [{'fractionOfPixels': 0.92, 'rgbValues': 'rgb_...

# %%
# IDENTIFY COLORS SKILL
bounding_boxes_msg= debug_utils.call_cortex_function(ident_bounding_boxes.main, payload=colors_msg['payload'])
ident_bounding_boxes.API.decode_dataframe_message(bounding_boxes_msg)
# Out:
#               comment                                          image_url  \
# 0        Eiffel Tower  https://www.kids-world-travel-guide.com/images...
# 1          Great Wall  https://www.kids-world-travel-guide.com/images...
# 2          Red Square  https://www.kids-world-travel-guide.com/images...
# 3       Leaning Tower  https://www.kids-world-travel-guide.com/images...
# 4      Great Pyramids  https://www.kids-world-travel-guide.com/images...
# 5  Sydney Opera House  https://www.kids-world-travel-guide.com/images...
# 6           Taj Mahal  https://www.kids-world-travel-guide.com/images...
#
#                                      dominant_colors  \
# 0  [{'fractionOfPixels': 0.68, 'rgbValues': 'rgb_...
# 1                                                 []
# 2  [{'fractionOfPixels': 0.12, 'rgbValues': 'rgb_...
# 3                                                 []
# 4  [{'fractionOfPixels': 0.14, 'rgbValues': 'rgb_...
# 5                                                 []
# 6  [{'fractionOfPixels': 0.92, 'rgbValues': 'rgb_...
#
#                                       bounding_boxes
# 0  [{'boundingPoly': [82, 36, 82, 80], 'confidenc...
# 1  [{'boundingPoly': [51, 90, 51, 37], 'confidenc...
# 2  [{'boundingPoly': [32, 71, 49, 40], 'confidenc...
# 3  [{'boundingPoly': [30, 13, 8, 8], 'confidence'...
# 4  [{'boundingPoly': [8, 44, 55, 73], 'confidence...
# 5  [{'boundingPoly': [40, 98, 90, 42], 'confidenc...
# 6  [{'boundingPoly': [13, 57, 61, 43], 'confidenc...

# %%
# IDENTIFY LANDMARKS SKILL
landmarks_msg= debug_utils.call_cortex_function(ident_landmarks.main, payload=bounding_boxes_msg['payload'])
ident_landmarks.API.decode_dataframe_message(landmarks_msg)
# Out:
#               comment                                          image_url  \
# 0        Eiffel Tower  https://www.kids-world-travel-guide.com/images...
# 1          Great Wall  https://www.kids-world-travel-guide.com/images...
# 2          Red Square  https://www.kids-world-travel-guide.com/images...
# 3       Leaning Tower  https://www.kids-world-travel-guide.com/images...
# 4      Great Pyramids  https://www.kids-world-travel-guide.com/images...
# 5  Sydney Opera House  https://www.kids-world-travel-guide.com/images...
# 6           Taj Mahal  https://www.kids-world-travel-guide.com/images...
#
#                                      dominant_colors  \
# 0  [{'fractionOfPixels': 0.68, 'rgbValues': 'rgb_...
# 1                                                 []
# 2  [{'fractionOfPixels': 0.12, 'rgbValues': 'rgb_...
# 3                                                 []
# 4  [{'fractionOfPixels': 0.14, 'rgbValues': 'rgb_...
# 5                                                 []
# 6  [{'fractionOfPixels': 0.92, 'rgbValues': 'rgb_...
#
#                                       bounding_boxes  \
# 0  [{'boundingPoly': [82, 36, 82, 80], 'confidenc...
# 1  [{'boundingPoly': [51, 90, 51, 37], 'confidenc...
# 2  [{'boundingPoly': [32, 71, 49, 40], 'confidenc...
# 3  [{'boundingPoly': [30, 13, 8, 8], 'confidence'...
# 4  [{'boundingPoly': [8, 44, 55, 73], 'confidence...
# 5  [{'boundingPoly': [40, 98, 90, 42], 'confidenc...
# 6  [{'boundingPoly': [13, 57, 61, 43], 'confidenc...
#
#                                            landmarks
# 0  [{'landmark': 'identified landmark', 'confiden...
# 1  [{'landmark': 'identified landmark', 'confiden...
# 2  [{'landmark': 'identified landmark', 'confiden...
# 3  [{'landmark': 'identified landmark', 'confiden...
# 4  [{'landmark': 'identified landmark', 'confiden...
# 5  [{'landmark': 'identified landmark', 'confiden...
# 6  [{'landmark': 'identified landmark', 'confiden...
