# %%
# %reload_ext autoreload
# %autoreload 2

# %%
#import cortex
import os
from pathlib import Path

from cortex import Cortex, Message

from image_pipeline.cortex_api import API

# %%
API.decode_dataframe_message

# %%
cortex = Cortex.client()

# %% [raw]
# action = cortex.action('bill/ident_bounding_boxes')
# action.get_deployment_status()

# %%
action = cortex.action('bill/ident_colors')
colors_rs = action.invoke(Message.with_payload({'ds_name': 'bill/test_images'}))
API.decode_dataframe_message({'payload': colors_rs.payload})
#colors_rs.payload
# Out:
#               comment                                          image_url  \
# 0        Eiffel Tower  https://www.kids-world-travel-guide.com/images...
# 1          Great Wall  https://www.kids-world-travel-guide.com/images...
# 2          Red Square  https://www.kids-world-travel-guide.com/images...
# 3       Leaning Tower  https://www.kids-world-travel-guide.com/images...
# 4      Great Pyramids  https://www.kids-world-travel-guide.com/images...
# 5  Sydney Opera House  https://www.kids-world-travel-guide.com/images...
# 6           Taj Mahal  https://www.kids-world-travel-guide.com/images...
#
#                                      dominant_colors
# 0  [{'fractionOfPixels': 0.98, 'rgbValues': 'rgb_...
# 1  [{'fractionOfPixels': 0.98, 'rgbValues': 'rgb_...
# 2  [{'fractionOfPixels': 0.59, 'rgbValues': 'rgb_...
# 3                                                 []
# 4  [{'fractionOfPixels': 0.59, 'rgbValues': 'rgb_...
# 5  [{'fractionOfPixels': 0.4, 'rgbValues': 'rgb_s...
# ...

# %%
action = cortex.action('bill/ident_bounding_boxes')
bounding_boxes_rs = action.invoke(Message.with_payload(colors_rs.payload))
API.decode_dataframe_message({'payload': bounding_boxes_rs.payload})
# Out:
#               comment                                          image_url  \
# 0        Eiffel Tower  https://www.kids-world-travel-guide.com/images...
# 1          Great Wall  https://www.kids-world-travel-guide.com/images...
# 2          Red Square  https://www.kids-world-travel-guide.com/images...
# 3       Leaning Tower  https://www.kids-world-travel-guide.com/images...
# 4      Great Pyramids  https://www.kids-world-travel-guide.com/images...
# 5  Sydney Opera House  https://www.kids-world-travel-guide.com/images...
# 6           Taj Mahal  https://www.kids-world-travel-guide.com/images...
#
#                                      dominant_colors  \
# 0  [{'fractionOfPixels': 0.91, 'rgbValues': 'rgb_...
# 1                                                 []
# 2  [{'fractionOfPixels': 0.35, 'rgbValues': 'rgb_...
# 3  [{'fractionOfPixels': 0.7, 'rgbValues': 'rgb_s...
# 4  [{'fractionOfPixels': 0.12, 'rgbValues': 'rgb_...
# 5  [{'fractionOfPixels': 0.18, 'rgbValues': 'rgb_...
# ...

# %%
action = cortex.action('bill/ident_landmarks')
landmarks_rs = action.invoke(Message.with_payload(bounding_boxes_rs.payload))
API.decode_dataframe_message({'payload': landmarks_rs.payload})
# Out:
#               comment                                          image_url  \
# 0        Eiffel Tower  https://www.kids-world-travel-guide.com/images...
# 1          Great Wall  https://www.kids-world-travel-guide.com/images...
# 2          Red Square  https://www.kids-world-travel-guide.com/images...
# 3       Leaning Tower  https://www.kids-world-travel-guide.com/images...
# 4      Great Pyramids  https://www.kids-world-travel-guide.com/images...
# 5  Sydney Opera House  https://www.kids-world-travel-guide.com/images...
# 6           Taj Mahal  https://www.kids-world-travel-guide.com/images...
#
#                                      dominant_colors  \
# 0  [{'fractionOfPixels': 0.91, 'rgbValues': 'rgb_...
# 1                                                 []
# 2  [{'fractionOfPixels': 0.35, 'rgbValues': 'rgb_...
# 3  [{'fractionOfPixels': 0.7, 'rgbValues': 'rgb_s...
# 4  [{'fractionOfPixels': 0.12, 'rgbValues': 'rgb_...
# 5  [{'fractionOfPixels': 0.18, 'rgbValues': 'rgb_...
# ...
